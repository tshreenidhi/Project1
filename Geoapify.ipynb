# %%
import requests
import folium
from IPython.display import display
import pandas as pd
from api_key import geoapify_key

# %%
api_key = geoapify_key
base_url = 'https://api.geoapify.com/v1/geocode/search'

top_cities = ['Los Angeles', 'San Jose	', 'San Francisco', 'San Diego', 'Sacramento']

for city in top_cities:
    params = {'text': city, 'apiKey': api_key}
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['features']:
        location = data['features'][0]['geometry']['coordinates']
        latitude, longitude = location[1], location[0]
        print(f"{city}: Latitude {latitude}, Longitude {longitude}")
    else:
        print(f"Location not found for {city}")
# Out:
# Los Angeles: Latitude 34.0536909, Longitude -118.242766
# San Jose	: Latitude 37.3361663, Longitude -121.890591
# San Francisco: Latitude 37.7790262, Longitude -122.419906
# San Diego: Latitude 32.7174202, Longitude -117.1627728
# Sacramento: Latitude 38.5810606, Longitude -121.493895

# %%
base_url = 'https://api.geoapify.com/v1/geocode/search'

data = {'pug_agency_name': ['Los Angeles', 'San Jose', 'San Francisco', 'San Diego', 'Sacramento'],
        'count': [1790, 352, 268, 215, 182]}

df = pd.DataFrame(data)

top_cities = df['pug_agency_name']

city_coordinates = {}

for city in top_cities:
    params = {'text': city, 'apiKey': api_key}
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['features']:
        location = data['features'][0]['geometry']['coordinates']
        latitude, longitude = location[1], location[0]
        city_coordinates[city] = (latitude, longitude)
        print(f"{city}: Latitude {latitude}, Longitude {longitude}")
    else:
        print(f"Location not found for {city}")

# Calculate map center
map_center = (sum(coord[0] for coord in city_coordinates.values()) / len(city_coordinates),
              sum(coord[1] for coord in city_coordinates.values()) / len(city_coordinates))

# Create a Folium map
my_map = folium.Map(location=map_center, zoom_start=6)

# Add markers for each city with custom pop-up content
for city, coordinates in city_coordinates.items():
    count = df[df['pug_agency_name'] == city]['count'].values[0]
    popup_content = f"City: {city} <br><br> Number of crimes: {count}"
    folium.Marker(location=coordinates, popup=popup_content).add_to(my_map)

# Display the map
display(my_map)
# Out:
# Los Angeles: Latitude 34.0536909, Longitude -118.242766
# San Jose: Latitude 37.3361663, Longitude -121.890591
# San Francisco: Latitude 37.7790262, Longitude -122.419906
# San Diego: Latitude 32.7174202, Longitude -117.1627728
# Sacramento: Latitude 38.5810606, Longitude -121.493895
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae79448e1b03e90bd1c5b19b67b3bd4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae79448e1b03e90bd1c5b19b67b3bd4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae79448e1b03e90bd1c5b19b67b3bd4d = L.map(
#                 &quot;map_ae79448e1b03e90bd1c5b19b67b3bd4d&quot;,
#                 {
#                     center: [36.09347284, -120.24198615999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fd9323d6d34076b8d92f0347dec1580 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5fd9323d6d34076b8d92f0347dec1580.addTo(map_ae79448e1b03e90bd1c5b19b67b3bd4d);
#
#
#             var marker_fc9b206c45065ce30e924c38eb077814 = L.marker(
#                 [34.0536909, -118.242766],
#                 {}
#             ).addTo(map_ae79448e1b03e90bd1c5b19b67b3bd4d);
#
#
#         var popup_63113e12375e35c7ebab6eb969d76dd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9d5392a25b8970cd616f2d4d61c3ed2 = $(`&lt;div id=&quot;html_f9d5392a25b8970cd616f2d4d61c3ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Los Angeles &lt;br&gt;&lt;br&gt; Number of crimes: 1790&lt;/div&gt;`)[0];
#                 popup_63113e12375e35c7ebab6eb969d76dd2.setContent(html_f9d5392a25b8970cd616f2d4d61c3ed2);
#
#
#
#         marker_fc9b206c45065ce30e924c38eb077814.bindPopup(popup_63113e12375e35c7ebab6eb969d76dd2)
#         ;
#
#
#
#
#             var marker_9f210ed4a3ff60c11d5cdd7b91375aaa = L.marker(
#                 [37.3361663, -121.890591],
#                 {}
#             ).addTo(map_ae79448e1b03e90bd1c5b19b67b3bd4d);
#
#
#         var popup_60edf55cd80fd7094241aad67974328f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7564f5a21939701c4a98399d8d9b2d86 = $(`&lt;div id=&quot;html_7564f5a21939701c4a98399d8d9b2d86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Jose &lt;br&gt;&lt;br&gt; Number of crimes: 352&lt;/div&gt;`)[0];
#                 popup_60edf55cd80fd7094241aad67974328f.setContent(html_7564f5a21939701c4a98399d8d9b2d86);
#
#
#
#         marker_9f210ed4a3ff60c11d5cdd7b91375aaa.bindPopup(popup_60edf55cd80fd7094241aad67974328f)
#         ;
#
#
#
#
#             var marker_a83fba436f762f336684b35870c4b4f6 = L.marker(
#                 [37.7790262, -122.419906],
#                 {}
#             ).addTo(map_ae79448e1b03e90bd1c5b19b67b3bd4d);
#
#
#         var popup_2f3df639d6a559170848114770c2064f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa00487e7efcb415b0e1a37a1cfda93f = $(`&lt;div id=&quot;html_fa00487e7efcb415b0e1a37a1cfda93f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Francisco &lt;br&gt;&lt;br&gt; Number of crimes: 268&lt;/div&gt;`)[0];
#                 popup_2f3df639d6a559170848114770c2064f.setContent(html_fa00487e7efcb415b0e1a37a1cfda93f);
#
#
#
#         marker_a83fba436f762f336684b35870c4b4f6.bindPopup(popup_2f3df639d6a559170848114770c2064f)
#         ;
#
#
#
#
#             var marker_45a7d11e5693705e07d559a38eae0bce = L.marker(
#                 [32.7174202, -117.1627728],
#                 {}
#             ).addTo(map_ae79448e1b03e90bd1c5b19b67b3bd4d);
#
#
#         var popup_3a77dad0f2fff4ab0df83b345467953c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5633511b917b0ccdcde6f08cc72cabc8 = $(`&lt;div id=&quot;html_5633511b917b0ccdcde6f08cc72cabc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Diego &lt;br&gt;&lt;br&gt; Number of crimes: 215&lt;/div&gt;`)[0];
#                 popup_3a77dad0f2fff4ab0df83b345467953c.setContent(html_5633511b917b0ccdcde6f08cc72cabc8);
#
#
#
#         marker_45a7d11e5693705e07d559a38eae0bce.bindPopup(popup_3a77dad0f2fff4ab0df83b345467953c)
#         ;
#
#
#
#
#             var marker_13f048f92e51b4cd15ba7df3d4a19bd4 = L.marker(
#                 [38.5810606, -121.493895],
#                 {}
#             ).addTo(map_ae79448e1b03e90bd1c5b19b67b3bd4d);
#
#
#         var popup_f74f0d87c64a79a820fdf5da43eda89f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2f241e416c4ddc425bfcb8eb73fe235 = $(`&lt;div id=&quot;html_e2f241e416c4ddc425bfcb8eb73fe235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Sacramento &lt;br&gt;&lt;br&gt; Number of crimes: 182&lt;/div&gt;`)[0];
#                 popup_f74f0d87c64a79a820fdf5da43eda89f.setContent(html_e2f241e416c4ddc425bfcb8eb73fe235);
#
#
#
#         marker_13f048f92e51b4cd15ba7df3d4a19bd4.bindPopup(pop

# %%
base_url = 'https://api.geoapify.com/v1/geocode/search'

data = {'pug_agency_name': ['Los Angeles', 'San Francisco', 'San Diego', 'San Jose', 'Long Beach'],
        'count': [299, 64, 54, 33, 23]}

df = pd.DataFrame(data)

top_cities = df['pug_agency_name']

city_coordinates = {}

for city in top_cities:
    params = {'text': city, 'apiKey': api_key}
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['features']:
        location = data['features'][0]['geometry']['coordinates']
        latitude, longitude = location[1], location[0]
        city_coordinates[city] = (latitude, longitude)
        print(f"{city}: Latitude {latitude}, Longitude {longitude}")
    else:
        print(f"Location not found for {city}")

# Calculate map center
map_center = (sum(coord[0] for coord in city_coordinates.values()) / len(city_coordinates),
              sum(coord[1] for coord in city_coordinates.values()) / len(city_coordinates))

# Create a Folium map
my_map = folium.Map(location=map_center, zoom_start=6)

# Add markers for each city with custom pop-up content
for city, coordinates in city_coordinates.items():
    count = df[df['pug_agency_name'] == city]['count'].values[0]
    popup_content = f"City: {city} <br><br> Number of crimes: {count}"
    folium.Marker(location=coordinates, popup=popup_content).add_to(my_map)

# Display the map
display(my_map)
my_map.save("crime_map_2019.html")
# Out:
# Los Angeles: Latitude 34.0536909, Longitude -118.242766
# San Francisco: Latitude 37.7790262, Longitude -122.419906
# San Diego: Latitude 32.7174202, Longitude -117.1627728
# San Jose: Latitude 37.3361663, Longitude -121.890591
# Long Beach: Latitude 33.7690164, Longitude -118.191604
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ba541ce55461e6953107d7144c2b96e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ba541ce55461e6953107d7144c2b96e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ba541ce55461e6953107d7144c2b96e = L.map(
#                 &quot;map_8ba541ce55461e6953107d7144c2b96e&quot;,
#                 {
#                     center: [35.131063999999995, -119.58152795999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef2dac27e3b2f83f62fa8092ff869987 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef2dac27e3b2f83f62fa8092ff869987.addTo(map_8ba541ce55461e6953107d7144c2b96e);
#
#
#             var marker_2835f9cc0299283c3e3b17bddd9cdb4a = L.marker(
#                 [34.0536909, -118.242766],
#                 {}
#             ).addTo(map_8ba541ce55461e6953107d7144c2b96e);
#
#
#         var popup_e967cffdb8fc494ce55e1676e5f1d0e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c779231fff3f1cbbff3da27856815d8 = $(`&lt;div id=&quot;html_0c779231fff3f1cbbff3da27856815d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Los Angeles &lt;br&gt;&lt;br&gt; Number of crimes: 299&lt;/div&gt;`)[0];
#                 popup_e967cffdb8fc494ce55e1676e5f1d0e7.setContent(html_0c779231fff3f1cbbff3da27856815d8);
#
#
#
#         marker_2835f9cc0299283c3e3b17bddd9cdb4a.bindPopup(popup_e967cffdb8fc494ce55e1676e5f1d0e7)
#         ;
#
#
#
#
#             var marker_6244c8aee784c51b25c49cc01cb5de02 = L.marker(
#                 [37.7790262, -122.419906],
#                 {}
#             ).addTo(map_8ba541ce55461e6953107d7144c2b96e);
#
#
#         var popup_ed25e7903359f611ca7b7a070219858b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6288e32dacc5cba4305f7f3221ed467 = $(`&lt;div id=&quot;html_d6288e32dacc5cba4305f7f3221ed467&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Francisco &lt;br&gt;&lt;br&gt; Number of crimes: 64&lt;/div&gt;`)[0];
#                 popup_ed25e7903359f611ca7b7a070219858b.setContent(html_d6288e32dacc5cba4305f7f3221ed467);
#
#
#
#         marker_6244c8aee784c51b25c49cc01cb5de02.bindPopup(popup_ed25e7903359f611ca7b7a070219858b)
#         ;
#
#
#
#
#             var marker_617feff1f310c79723373aaa7f1bf5f3 = L.marker(
#                 [32.7174202, -117.1627728],
#                 {}
#             ).addTo(map_8ba541ce55461e6953107d7144c2b96e);
#
#
#         var popup_172705b3ac9e927ebf846e8a8f2b92e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3acba158445277e4e5d030ef0bf1cfd8 = $(`&lt;div id=&quot;html_3acba158445277e4e5d030ef0bf1cfd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Diego &lt;br&gt;&lt;br&gt; Number of crimes: 54&lt;/div&gt;`)[0];
#                 popup_172705b3ac9e927ebf846e8a8f2b92e8.setContent(html_3acba158445277e4e5d030ef0bf1cfd8);
#
#
#
#         marker_617feff1f310c79723373aaa7f1bf5f3.bindPopup(popup_172705b3ac9e927ebf846e8a8f2b92e8)
#         ;
#
#
#
#
#             var marker_1ad9914de79981b094e6965dbad791a3 = L.marker(
#                 [37.3361663, -121.890591],
#                 {}
#             ).addTo(map_8ba541ce55461e6953107d7144c2b96e);
#
#
#         var popup_3807421d0705b8b29ba5b9db5091a2ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4978a85fc150092ce9f0856e1aa197d7 = $(`&lt;div id=&quot;html_4978a85fc150092ce9f0856e1aa197d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Jose &lt;br&gt;&lt;br&gt; Number of crimes: 33&lt;/div&gt;`)[0];
#                 popup_3807421d0705b8b29ba5b9db5091a2ce.setContent(html_4978a85fc150092ce9f0856e1aa197d7);
#
#
#
#         marker_1ad9914de79981b094e6965dbad791a3.bindPopup(popup_3807421d0705b8b29ba5b9db5091a2ce)
#         ;
#
#
#
#
#             var marker_6054f948931edd3405a472e8f1d0af02 = L.marker(
#                 [33.7690164, -118.191604],
#                 {}
#             ).addTo(map_8ba541ce55461e6953107d7144c2b96e);
#
#
#         var popup_7b33e262bc541e47f9d7e82480b3326e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15bf925ab47ab4bc970d9eb39935912f = $(`&lt;div id=&quot;html_15bf925ab47ab4bc970d9eb39935912f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Long Beach &lt;br&gt;&lt;br&gt; Number of crimes: 23&lt;/div&gt;`)[0];
#                 popup_7b33e262bc541e47f9d7e82480b3326e.setContent(html_15bf925ab47ab4bc970d9eb39935912f);
#
#
#
#         marker_6054f948931edd3405a472e8f1d0af02.bindPopup(p

# %%
# For 2020
base_url = 'https://api.geoapify.com/v1/geocode/search'

data = {'pug_agency_name': ['Los Angeles', 'San Jose', 'San Francisco', 'San Diego', 'Oakland'],
        'count': [394, 94, 54, 45, 19]}

df = pd.DataFrame(data)

top_cities = df['pug_agency_name']

city_coordinates = {}

for city in top_cities:
    params = {'text': city, 'apiKey': api_key}
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['features']:
        location = data['features'][0]['geometry']['coordinates']
        latitude, longitude = location[1], location[0]
        city_coordinates[city] = (latitude, longitude)
        print(f"{city}: Latitude {latitude}, Longitude {longitude}")
    else:
        print(f"Location not found for {city}")

# Calculate map center
map_center = (sum(coord[0] for coord in city_coordinates.values()) / len(city_coordinates),
              sum(coord[1] for coord in city_coordinates.values()) / len(city_coordinates))

# Create a Folium map
my_map = folium.Map(location=map_center, zoom_start=6)

# Add markers for each city with custom pop-up content
for city, coordinates in city_coordinates.items():
    count = df[df['pug_agency_name'] == city]['count'].values[0]
    popup_content = f"City: {city} <br><br> Number of crimes: {count}"
    folium.Marker(location=coordinates, popup=popup_content).add_to(my_map)

# Display the map
display(my_map)
my_map.save("crime_map_2020.html")
# Out:
# Los Angeles: Latitude 34.0536909, Longitude -118.242766
# San Jose: Latitude 37.3361663, Longitude -121.890591
# San Francisco: Latitude 37.7790262, Longitude -122.419906
# San Diego: Latitude 32.7174202, Longitude -117.1627728
# Oakland: Latitude 37.8044557, Longitude -122.271356
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc687d9fe4b6dea0725925bcff470021 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc687d9fe4b6dea0725925bcff470021&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc687d9fe4b6dea0725925bcff470021 = L.map(
#                 &quot;map_fc687d9fe4b6dea0725925bcff470021&quot;,
#                 {
#                     center: [35.93815186, -120.39747836],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc96edb0f96e80a8f8ea18ed2de53a73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc96edb0f96e80a8f8ea18ed2de53a73.addTo(map_fc687d9fe4b6dea0725925bcff470021);
#
#
#             var marker_108f8364657e2858b0d6bacf28685439 = L.marker(
#                 [34.0536909, -118.242766],
#                 {}
#             ).addTo(map_fc687d9fe4b6dea0725925bcff470021);
#
#
#         var popup_1f7b82c1bdaaefddfbc5be9ea18bc45d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea05de14de3135904b2b1665c3992a7d = $(`&lt;div id=&quot;html_ea05de14de3135904b2b1665c3992a7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Los Angeles &lt;br&gt;&lt;br&gt; Number of crimes: 394&lt;/div&gt;`)[0];
#                 popup_1f7b82c1bdaaefddfbc5be9ea18bc45d.setContent(html_ea05de14de3135904b2b1665c3992a7d);
#
#
#
#         marker_108f8364657e2858b0d6bacf28685439.bindPopup(popup_1f7b82c1bdaaefddfbc5be9ea18bc45d)
#         ;
#
#
#
#
#             var marker_79f189adc97e9faf5b95f25ad64dd365 = L.marker(
#                 [37.3361663, -121.890591],
#                 {}
#             ).addTo(map_fc687d9fe4b6dea0725925bcff470021);
#
#
#         var popup_21b2a9d37b0d9067e8f7a600e6dd5117 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17d3cad72db06400fb315a338f20b99f = $(`&lt;div id=&quot;html_17d3cad72db06400fb315a338f20b99f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Jose &lt;br&gt;&lt;br&gt; Number of crimes: 94&lt;/div&gt;`)[0];
#                 popup_21b2a9d37b0d9067e8f7a600e6dd5117.setContent(html_17d3cad72db06400fb315a338f20b99f);
#
#
#
#         marker_79f189adc97e9faf5b95f25ad64dd365.bindPopup(popup_21b2a9d37b0d9067e8f7a600e6dd5117)
#         ;
#
#
#
#
#             var marker_c1f6bd7a5e649bd70b6dd9b762e505be = L.marker(
#                 [37.7790262, -122.419906],
#                 {}
#             ).addTo(map_fc687d9fe4b6dea0725925bcff470021);
#
#
#         var popup_3a5df048faee4ddcd397c1e8c106f610 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f01f13037b3d02e3b6c5c3e5a5832a14 = $(`&lt;div id=&quot;html_f01f13037b3d02e3b6c5c3e5a5832a14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Francisco &lt;br&gt;&lt;br&gt; Number of crimes: 54&lt;/div&gt;`)[0];
#                 popup_3a5df048faee4ddcd397c1e8c106f610.setContent(html_f01f13037b3d02e3b6c5c3e5a5832a14);
#
#
#
#         marker_c1f6bd7a5e649bd70b6dd9b762e505be.bindPopup(popup_3a5df048faee4ddcd397c1e8c106f610)
#         ;
#
#
#
#
#             var marker_098dacd024ee2acedd86879e5df540a7 = L.marker(
#                 [32.7174202, -117.1627728],
#                 {}
#             ).addTo(map_fc687d9fe4b6dea0725925bcff470021);
#
#
#         var popup_d119bade6e05be63f25daa55934fd379 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8b2c223ff5bce4a0d164f01c2015235 = $(`&lt;div id=&quot;html_d8b2c223ff5bce4a0d164f01c2015235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Diego &lt;br&gt;&lt;br&gt; Number of crimes: 45&lt;/div&gt;`)[0];
#                 popup_d119bade6e05be63f25daa55934fd379.setContent(html_d8b2c223ff5bce4a0d164f01c2015235);
#
#
#
#         marker_098dacd024ee2acedd86879e5df540a7.bindPopup(popup_d119bade6e05be63f25daa55934fd379)
#         ;
#
#
#
#
#             var marker_36c37849d372a76470acdd70301571dd = L.marker(
#                 [37.8044557, -122.271356],
#                 {}
#             ).addTo(map_fc687d9fe4b6dea0725925bcff470021);
#
#
#         var popup_223b7c9f08ec66fdce839e4c58ac80c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86d000c542974142366574e450cfa682 = $(`&lt;div id=&quot;html_86d000c542974142366574e450cfa682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Oakland &lt;br&gt;&lt;br&gt; Number of crimes: 19&lt;/div&gt;`)[0];
#                 popup_223b7c9f08ec66fdce839e4c58ac80c1.setContent(html_86d000c542974142366574e450cfa682);
#
#
#
#         marker_36c37849d372a76470acdd70301571dd.bindPopup(popup_223b7c9f08e

# %%
# For 2021
base_url = 'https://api.geoapify.com/v1/geocode/search'

data = {'pug_agency_name': ['Los Angeles', 'San Jose', 'San Francisco', 'Sacramento', 'San Diego'],
        'count': [461, 117, 114, 67, 61]}

df = pd.DataFrame(data)

top_cities = df['pug_agency_name']

city_coordinates = {}

for city in top_cities:
    params = {'text': city, 'apiKey': api_key}
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['features']:
        location = data['features'][0]['geometry']['coordinates']
        latitude, longitude = location[1], location[0]
        city_coordinates[city] = (latitude, longitude)
        print(f"{city}: Latitude {latitude}, Longitude {longitude}")
    else:
        print(f"Location not found for {city}")

# Calculate map center
map_center = (sum(coord[0] for coord in city_coordinates.values()) / len(city_coordinates),
              sum(coord[1] for coord in city_coordinates.values()) / len(city_coordinates))

# Create a Folium map
my_map = folium.Map(location=map_center, zoom_start=6)

# Add markers for each city with custom pop-up content
for city, coordinates in city_coordinates.items():
    count = df[df['pug_agency_name'] == city]['count'].values[0]
    popup_content = f"City: {city} <br><br> Number of crimes: {count}"
    folium.Marker(location=coordinates, popup=popup_content).add_to(my_map)

# Display the map
display(my_map)
my_map.save("crime_map_2021.html")
# Out:
# Los Angeles: Latitude 34.0536909, Longitude -118.242766
# San Jose: Latitude 37.3361663, Longitude -121.890591
# San Francisco: Latitude 37.7790262, Longitude -122.419906
# Sacramento: Latitude 38.5810606, Longitude -121.493895
# San Diego: Latitude 32.7174202, Longitude -117.1627728
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cbcd30f2626fb763a707a14fd926cad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cbcd30f2626fb763a707a14fd926cad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cbcd30f2626fb763a707a14fd926cad = L.map(
#                 &quot;map_5cbcd30f2626fb763a707a14fd926cad&quot;,
#                 {
#                     center: [36.09347284, -120.24198616000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3741b2c4302473bca12500810ee069fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3741b2c4302473bca12500810ee069fb.addTo(map_5cbcd30f2626fb763a707a14fd926cad);
#
#
#             var marker_67a443c55ab3ee9e46ed48cab0c78c39 = L.marker(
#                 [34.0536909, -118.242766],
#                 {}
#             ).addTo(map_5cbcd30f2626fb763a707a14fd926cad);
#
#
#         var popup_a1b5a7e9de5dbeea6eeebf408d6e8872 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a5cad979fa355466ed1d2267f493b22 = $(`&lt;div id=&quot;html_8a5cad979fa355466ed1d2267f493b22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Los Angeles &lt;br&gt;&lt;br&gt; Number of crimes: 461&lt;/div&gt;`)[0];
#                 popup_a1b5a7e9de5dbeea6eeebf408d6e8872.setContent(html_8a5cad979fa355466ed1d2267f493b22);
#
#
#
#         marker_67a443c55ab3ee9e46ed48cab0c78c39.bindPopup(popup_a1b5a7e9de5dbeea6eeebf408d6e8872)
#         ;
#
#
#
#
#             var marker_a5b5285c8bb64ebda930e51af761f07b = L.marker(
#                 [37.3361663, -121.890591],
#                 {}
#             ).addTo(map_5cbcd30f2626fb763a707a14fd926cad);
#
#
#         var popup_796878db80622db137516b81bdec2ce5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_613be2c64023595a34bd929204038e71 = $(`&lt;div id=&quot;html_613be2c64023595a34bd929204038e71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Jose &lt;br&gt;&lt;br&gt; Number of crimes: 117&lt;/div&gt;`)[0];
#                 popup_796878db80622db137516b81bdec2ce5.setContent(html_613be2c64023595a34bd929204038e71);
#
#
#
#         marker_a5b5285c8bb64ebda930e51af761f07b.bindPopup(popup_796878db80622db137516b81bdec2ce5)
#         ;
#
#
#
#
#             var marker_a4a31b2dc4dc4b4323d15225329d93d0 = L.marker(
#                 [37.7790262, -122.419906],
#                 {}
#             ).addTo(map_5cbcd30f2626fb763a707a14fd926cad);
#
#
#         var popup_3efac2ccbfb027aa0fe9670e1dee8c4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cff8ca8af3b1d1b77059a87fbacc7888 = $(`&lt;div id=&quot;html_cff8ca8af3b1d1b77059a87fbacc7888&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Francisco &lt;br&gt;&lt;br&gt; Number of crimes: 114&lt;/div&gt;`)[0];
#                 popup_3efac2ccbfb027aa0fe9670e1dee8c4f.setContent(html_cff8ca8af3b1d1b77059a87fbacc7888);
#
#
#
#         marker_a4a31b2dc4dc4b4323d15225329d93d0.bindPopup(popup_3efac2ccbfb027aa0fe9670e1dee8c4f)
#         ;
#
#
#
#
#             var marker_5904cb93314fd2d65496c1c5bfeb9667 = L.marker(
#                 [38.5810606, -121.493895],
#                 {}
#             ).addTo(map_5cbcd30f2626fb763a707a14fd926cad);
#
#
#         var popup_e026a0c694d2639da3400db4a2730f41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3df15eee844c67804a9519b2a72b1de = $(`&lt;div id=&quot;html_e3df15eee844c67804a9519b2a72b1de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Sacramento &lt;br&gt;&lt;br&gt; Number of crimes: 67&lt;/div&gt;`)[0];
#                 popup_e026a0c694d2639da3400db4a2730f41.setContent(html_e3df15eee844c67804a9519b2a72b1de);
#
#
#
#         marker_5904cb93314fd2d65496c1c5bfeb9667.bindPopup(popup_e026a0c694d2639da3400db4a2730f41)
#         ;
#
#
#
#
#             var marker_e0375ed2997054c1fdc2bcea80434a15 = L.marker(
#                 [32.7174202, -117.1627728],
#                 {}
#             ).addTo(map_5cbcd30f2626fb763a707a14fd926cad);
#
#
#         var popup_7276ceafd93f368a7aa4628d627877cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb5419ebe99c666dc5646b49261fc8d4 = $(`&lt;div id=&quot;html_bb5419ebe99c666dc5646b49261fc8d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: San Diego &lt;br&gt;&lt;br&gt; Number of crimes: 61&lt;/div&gt;`)[0];
#                 popup_7276ceafd93f368a7aa4628d627877cb.setContent(html_bb5419ebe99c666dc5646b49261fc8d4);
#
#
#
#         marker_e0375ed2997054c1fdc2bcea80434a15.bindPopup(popup_

# %%
# For 2022

api_key = '29824a9aca744f7fb64c065e93cd1073'
base_url = 'https://api.geoapify.com/v1/geocode/search'

data = {'pug_agency_name': ['Los Angeles', 'San Jose', 'Sacramento', 'San Diego', 'Berkeley'],
        'count': [636, 108, 93, 55, 40]}

df = pd.DataFrame(data)

top_cities = df['pug_agency_name']

city_coordinates = {}

for city in top_cities:
    params = {'text': city, 'apiKey': api_key}
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['features']:
        location = data['features'][0]['geometry']['coordinates']
        latitude, longitude = location[1], location[0]
        city_coordinates[city] = (latitude, longitude)
        print(f"{city}: Latitude {latitude}, Longitude {longitude}")
    else:
        print(f"Location not found for {city}")

# Calculate map center
map_center = (sum(coord[0] for coord in city_coordinates.values()) / len(city_coordinates),
              sum(coord[1] for coord in city_coordinates.values()) / len(city_coordinates))

# Create a Folium map
my_map = folium.Map(location=map_center, zoom_start=6)

# Add markers for each city with custom pop-up content
for city, coordinates in city_coordinates.items():
    count = df[df['pug_agency_name'] == city]['count'].values[0]
    popup_content = f"City: {city} <br><br> Number of crimes: {count}"
    folium.Marker(location=coordinates, popup=popup_content).add_to(my_map)

# Display the map
display(my_map)
my_map.save("crime_map_2022.html")
